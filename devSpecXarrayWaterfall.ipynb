# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/atsushi/.anyenv/envs/pyenv/versions/3.8.1/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['step']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
# %run ../../python_scripts/tools.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.anyenv/envs/pyenv/versions/3.8.1/lib/python3.8/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~/.anyenv/envs/pyenv/versions/3.8.1/lib/python3.8/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'../../python_scripts/tools.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-15-25501647c8cc> in <module>
# ----> 1 get_ipython().run_line_magic('run', '../../python_scripts/tools.py')
#
# ~/.anyenv/envs/pyenv/versions/3.8.1/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# ~/.anyenv/envs/pyenv/versions/3.8.1/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/.anyenv/envs/pyenv/versions/3.8.1/lib/python3.8/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'../../python_scripts/tools.py'` not found.

# %%
import os
from os.path import join, exists
import xarray as xr

# %%
# %run ../tools_leprecon.py
# basepath = r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20200824'
basepath = join(os.path.expanduser('~'), 'works', 'MyLeprecon', 'SpectrometerData', '20200824')
ls = os.listdir(basepath)

# %%
# font_setup(size=20)

# %%
ls = os.listdir(basepath)
ls = [i for i in ls if '4s' in i]
step = 5e6
fig=gcf()
fig.set_facecolor('w')
fig.set_size_inches([30,45])

for i,f in enumerate(ls[:]):
    fp = join(basepath, f)
    data = xr.open_dataset(fp)
    image_data = data.to_array()[0]
    plot(image_data.sum(axis=0)+i*step,'k')


[text(-120,2.6e6+step*i,t[6:-4],color='r') for i,t in enumerate(ls)]
xlim(-170,2100)

xlabel('pixel')
ylabel('intensity')
gritix()
#savefig('../img/hespectra.pdf',dpi=200,bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e0438e138895> in <module>
#      18 xlabel('pixel')
#      19 ylabel('intensity')
# ---> 20 gritix()
#      21 #savefig('../img/hespectra.pdf',dpi=200,bbox_inches='tight')
#
# NameError: name 'gritix' is not defined

# %%
#R = [f'{i}.fit' for i in [300000,301000,305000,310000,315000,350000,400000]]
R = [f'{300000 + 5000*i}.fit' for i in range(81)]

# %%
[i for i in R if '410000' in i or '415000' in i]
# Out:
# ['410000.fit', '415000.fit']

# %%
1000/300*1500
# Out:
# 5000.0
